# %%
import pandas as pd

# Load dataset
mahasiswa = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/Data Mahasiswa/Data Pribadi Mahasiswa 2024.xlsx", dtype={"NISN": str})  # Berisi informasi pribadi
ipk = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/IPK/IPK 2024.xlsx")  # Berisi IPK per mahasiswa
khs = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/KHS/Cleaned_KHS_2024.xlsx")  # Berisi nilai per mata kuliah per semester

# Pastikan kolom NIM dalam format string agar tidak terjadi mismatch
mahasiswa["NIM"] = mahasiswa["NIM"].astype(str)
ipk["NIM"] = ipk["NIM"].astype(str)
khs["NIM"] = khs["NIM"].astype(str)

# Gabungkan Data Mahasiswa dan IPK (One-to-One Join)
df_merged = pd.merge(mahasiswa, ipk, on="NIM", how="left")

# Gabungkan dengan KHS (One-to-Many Join, karena satu mahasiswa punya banyak mata kuliah)
df_final = pd.merge(df_merged, khs, on="NIM", how="left")

# Simpan hasil merge
df_final.to_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/dataset_gabungan_2024.xlsx", index=False)

# Tampilkan beberapa baris pertama untuk verifikasi
df_final
# Out:
#       No._x        NIM                  Nama_x               NIK      JK  \
# 0         1  110124001   ANANDA YUFA NURHALIZA  3276026504030008  Wanita
# 1         1  110124001   ANANDA YUFA NURHALIZA  3276026504030008  Wanita
# 2         1  110124001   ANANDA YUFA NURHALIZA  3276026504030008  Wanita
# 3         1  110124001   ANANDA YUFA NURHALIZA  3276026504030008  Wanita
# 4         1  110124001   ANANDA YUFA NURHALIZA  3276026504030008  Wanita
# ...     ...        ...                     ...               ...     ...
# 2043    256  110124257  SEPHIA INNAYATUL MAULA  3671116707060005  Wanita
# 2044    256  110124257  SEPHIA INNAYATUL MAULA  3671116707060005  Wanita
# 2045    256  110124257  SEPHIA INNAYATUL MAULA  3671116707060005  Wanita
# 2046    256  110124257  SEPHIA INNAYATUL MAULA  3671116707060005  Wanita
# 2047    256  110124257  SEPHIA INNAYATUL MAULA  3671116707060005  Wanita
#
#       Agama Kelas Perkuliahan Tempat Lahir        Tanggal Lahir  \
# 0     Islam            24SI12      JAKARTA  2003-04-25 00:00:00
# 1     Islam            24SI12      JAKARTA  2003-04-25 00:00:00
# 2     Islam            24SI12      JAKARTA  2003-04-25 00:00:00
# 3     Islam            24SI12      JAKARTA  2003-04-25 00:00:00
# 4     Islam            24SI12      JAKARTA  2003-04-25 00:00:00
# ...     ...               ...          ...                  ...
# 2043  Islam            24SI02    TANGERANG         27 Juli 2006
# 2044  Islam            24SI02    TANGERANG         27 Juli 2006
# 2045  Islam            24SI02    TANGERANG         27 Juli 2006
# 2046  Islam            24SI02    TANGERANG         27 Juli 2006
# 2047  Islam            24SI02    TANGERANG         27 Juli 2006
#
#                                                  Alamat  ...  Sistem Kuliah  \
# 0                         depok sawangan, RT/RW 002/006  ...        Reguler
# 1                         depok sawangan, RT/RW 002/006  ...        Reguler
# 2                         depok sawangan, RT/RW 002/006  ...        Reguler
# 3                         depok sawangan, RT/RW 002/006  ...        Reguler
# 4                         depok sawangan, RT/RW 002/006  ...        Reguler
# ...                                                 ...  ...            ...
# 2043  Metland Cileungsi Sektor 6, Blok Fi10 No14, Ci...  ...        Reguler
# 2044  Metland Cileungsi Sektor 6, Blok Fi10 No14, Ci...  ...        Reguler
# 2045  Metland Cileungsi Sektor 6, Blok Fi10 No14, Ci...  ...        Reguler
# 2046  Metland Cileungsi Sektor 6, Blok Fi10 No14, Ci...  ...        Reguler
# 2047  Metland Cileungsi Sektor 6, Blok Fi10 No14, Ci...  ...        Reguler
#
#       IPK Lulus IPK Total                    Nama     Program Studi  \
# 0          3.49      3.49   ANANDA YUFA NURHALIZA  Sistem Informasi
# 1          3.49      3.49   ANANDA YUFA NURHALIZA  Sistem Informasi
# 2          3.49      3.49   ANANDA YUFA NURHALIZA  Sistem Informasi
# 3          3.49      3.49   ANANDA YUFA NURHALIZA  Sistem Informasi
# 4          3.49      3.49   ANANDA YUFA NURHALIZA  Sistem Informasi
# ...         ...       ...                     ...               ...
# 2043       2.67      2.67  SEPHIA INNAYATUL MAULA  Sistem Informasi
# 2044       2.67      2.67  SEPHIA INNAYATUL MAULA  Sistem Informasi
# 2045       2.67      2.67  SEPHIA INNAYATUL MAULA  Sistem Informasi
# 2046       2.67      2.67  SEPHIA INNAYATUL MAULA  Sistem Informasi
# 2047       2.67      2.67  SEPHIA INNAYATUL MAULA  Sistem Informasi
#
#                 Pembimbing Akademik Semester               Nama Mata Kuliah  \
# 0         Akhmam Fahmi, S.Mat, M.Pd        1            MATEMATIKA KOMPUTER
# 1         Akhmam Fahmi, S.Mat, M.Pd        1        DASAR DASAR PEMROGRAMAN
# 2         Akhmam Fahmi, S.Mat, M.Pd        1  PENGANTAR TEKNOLOGI INFORMASI
# 3         Akhmam Fahmi, S.Mat, M.Pd        1                 SISTEM OPERASI
# 4         Akhmam Fahmi, S.Mat, M.Pd        1              PEMROGRAMAN WEB 1
# ...                             ...      ...                            ...
# 2043  SUHENDI, S.T, S.KOM., M.M.S.I        1                 SISTEM OPERASI
# 2044  SUHENDI, S.T, S.KOM., M.M.S.I        1              PEMROGRAMAN WEB 1
# 2045  SUHENDI, S.T, S.KOM., M.M.S.I        1               PENDIDIKAN AGAMA
# 2046  SUHENDI, S.T, S.KOM., M.M.S.I        1               BAHASA INDONESIA
# 2047  SUHENDI, S.T, S.KOM., M.M.S.I        1           PEMBENTUKAN KARAKTER
#
#       SKS Nilai Akhir
# 0       3           B
# 1       3           A
# 2       3           A
# 3       3           B
# 4       3          B+
# ...   ...         ...
# 2043    3           B
# 2044    3          C+
# 2045    2          C+
# 2046    2          B+
# 2047    2           A
#
# [2048 rows x 48 columns]

# %%
import pandas as pd

# Load dataset
mahasiswa = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/Data Mahasiswa/Data Pribadi Mahasiswa 2024.xlsx")  # Berisi informasi pribadi
ipk = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/IPK/IPK 2024.xlsx")  # Berisi IPK per mahasiswa
khs = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/KHS/Cleaned_KHS_2024.xlsx")  # Berisi nilai per mata kuliah per semester

# Pastikan kolom NIM dalam format string agar tidak terjadi mismatch
mahasiswa["NIM"] = mahasiswa["NIM"].astype(str)
ipk["NIM"] = ipk["NIM"].astype(str)
khs["NIM"] = khs["NIM"].astype(str)

# Gabungkan Data Mahasiswa dan IPK (One-to-One Join)
df_merged = pd.merge(mahasiswa, ipk, on="NIM", how="left")

# Gabungkan dengan KHS (One-to-Many Join, karena satu mahasiswa punya banyak mata kuliah)
df_final = pd.merge(df_merged, khs, on="NIM", how="left")

# Tentukan batasan untuk risiko lulus tepat waktu
IPK_MIN = 2.75  # IPK minimum untuk mahasiswa aman
RISK_GRADES = ['D', 'E']  # Nilai yang dianggap sebagai risiko

# Fungsi untuk menghitung rata-rata nilai akhir mahasiswa
def hitung_nilai_rata_rata(nim, df_khs):
    # Hitung rata-rata nilai untuk setiap mahasiswa berdasarkan NIM
    nilai_mapping = {'A': 4, 'A-': 3.7, 'B+': 3.3, 'B': 3, 'B-': 2.7, 'C+': 2.3, 'C': 2, 'C-': 1.7, 'D': 1, 'E': 0}
    nilai_mahasiswa = df_khs[df_khs['NIM'] == nim]['Nilai Akhir'].map(nilai_mapping)
    return nilai_mahasiswa.mean()

# Fungsi untuk menentukan apakah mahasiswa berisiko
def risiko_lulus(row):
    # Cek IPK
    ipk_risiko = row['IPK Total'] < IPK_MIN

    # Cek nilai rata-rata (apakah ada nilai D atau E yang dianggap berisiko?)
    nilai_rata_rata = hitung_nilai_rata_rata(row['NIM'], khs)
    nilai_risiko = nilai_rata_rata < 2.75  # Jika nilai rata-rata kurang dari 2.75, berisiko

    # Jika salah satu kondisi risiko terpenuhi, mahasiswa dianggap berisiko
    if ipk_risiko or nilai_risiko:
        return 'Berpotensi Terlambat'
    return 'Aman'

# Terapkan fungsi risiko_lulus ke setiap baris dalam dataset
df_final['Risiko Lulus'] = df_final.apply(risiko_lulus, axis=1)

# Simpan hasil gabungan dan penambahan kriteria risiko
df_final.to_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/dataset_risiko_gabungan_2024.xlsx", index=False)

# Tampilkan beberapa baris pertama untuk verifikasi
df_final.head()
# Out:
#    No._x        NIM                 Nama_x               NIK      JK  Agama  \
# 0      1  110124001  ANANDA YUFA NURHALIZA  3276026504030008  Wanita  Islam
# 1      1  110124001  ANANDA YUFA NURHALIZA  3276026504030008  Wanita  Islam
# 2      1  110124001  ANANDA YUFA NURHALIZA  3276026504030008  Wanita  Islam
# 3      1  110124001  ANANDA YUFA NURHALIZA  3276026504030008  Wanita  Islam
# 4      1  110124001  ANANDA YUFA NURHALIZA  3276026504030008  Wanita  Islam
#
#   Kelas Perkuliahan Tempat Lahir        Tanggal Lahir  \
# 0            24SI12      JAKARTA  2003-04-25 00:00:00
# 1            24SI12      JAKARTA  2003-04-25 00:00:00
# 2            24SI12      JAKARTA  2003-04-25 00:00:00
# 3            24SI12      JAKARTA  2003-04-25 00:00:00
# 4            24SI12      JAKARTA  2003-04-25 00:00:00
#
#                           Alamat  ...  IPK Lulus  IPK Total  \
# 0  depok sawangan, RT/RW 002/006  ...       3.49       3.49
# 1  depok sawangan, RT/RW 002/006  ...       3.49       3.49
# 2  depok sawangan, RT/RW 002/006  ...       3.49       3.49
# 3  depok sawangan, RT/RW 002/006  ...       3.49       3.49
# 4  depok sawangan, RT/RW 002/006  ...       3.49       3.49
#
#                     Nama     Program Studi        Pembimbing Akademik  \
# 0  ANANDA YUFA NURHALIZA  Sistem Informasi  Akhmam Fahmi, S.Mat, M.Pd
# 1  ANANDA YUFA NURHALIZA  Sistem Informasi  Akhmam Fahmi, S.Mat, M.Pd
# 2  ANANDA YUFA NURHALIZA  Sistem Informasi  Akhmam Fahmi, S.Mat, M.Pd
# 3  ANANDA YUFA NURHALIZA  Sistem Informasi  Akhmam Fahmi, S.Mat, M.Pd
# 4  ANANDA YUFA NURHALIZA  Sistem Informasi  Akhmam Fahmi, S.Mat, M.Pd
#
#   Semester               Nama Mata Kuliah  SKS  Nilai Akhir Risiko Lulus
# 0        1            MATEMATIKA KOMPUTER    3            B         Aman
# 1        1        DASAR DASAR PEMROGRAMAN    3            A         Aman
# 2        1  PENGANTAR TEKNOLOGI INFORMASI    3            A         Aman
# 3        1                 SISTEM OPERASI    3            B         Aman
# 4        1              PEMROGRAMAN WEB 1    3           B+         Aman
#
# [5 rows x 49 columns]

# %%
import pandas as pd

# Load dataset
mahasiswa = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/Data Mahasiswa/Data Pribadi Mahasiswa 2024.xlsx")
ipk = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/IPK/IPK 2024.xlsx")
khs = pd.read_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/KHS/Cleaned_KHS_2024.xlsx")

# Format NIM ke string
for df in [mahasiswa, ipk, khs]:
    df["NIM"] = df["NIM"].astype(str)

# Mapping nilai
nilai_mapping = {'A': 4, 'A-': 3.7, 'B+': 3.3, 'B': 3, 'B-': 2.7, 'C+': 2.3, 'C': 2, 'C-': 1.7, 'D': 1, 'E': 0}
khs["Skor"] = khs["Nilai Akhir"].map(nilai_mapping)

# Ambil nilai tertinggi untuk matkul yang sama
khs = khs.sort_values(by=["NIM", "Nama Mata Kuliah", "Skor"], ascending=[True, True, False])
khs = khs.drop_duplicates(subset=["NIM", "Nama Mata Kuliah"], keep="first")

# Gabungkan data
df_merged = pd.merge(mahasiswa, ipk, on="NIM", how="left")
df_final = pd.merge(df_merged, khs, on="NIM", how="left")

# Tetapkan batas
IPK_MIN = 2.75
RISK_GRADES = ['C-', 'D', 'E']
batas_sks = {1: 20, 2: 20, 3: 21, 4: 20, 5: 20}

# Hitung total SKS per mahasiswa per semester (tanpa matkul E)
sks_per_semester = khs[~khs["Nilai Akhir"].isin(['C-', 'D', 'E'])].groupby(["NIM", "Semester"])["SKS"].sum().reset_index()
sks_per_semester.rename(columns={"SKS": "Total SKS"}, inplace=True)

# Gabungkan ke data final
df_final = pd.merge(df_final, sks_per_semester, on=["NIM", "Semester"], how="left")

# Tambahkan status SKS
def status_sks(row):
    batas = batas_sks.get(row['Semester'], 0)
    if pd.isna(row['Total SKS']) or row['Total SKS'] == 0:
        return "Tidak Aktif"
    elif row['Total SKS'] < batas:
        return "SKS Kurang"
    else:
        return "Aktif"

df_final["Status SKS"] = df_final.apply(status_sks, axis=1)

# Hitung IPS per baris (satu kolom)
def hitung_ips_baris(row, df_khs):
    nim = row['NIM']
    semester = row['Semester']
    data = df_khs[(df_khs['NIM'] == nim) & (df_khs['Semester'] == semester)]
    if data.empty or data['SKS'].sum() == 0:
        return None
    return round((data['SKS'] * data['Skor']).sum() / data['SKS'].sum(), 2)

df_final["IPS"] = df_final.apply(lambda row: hitung_ips_baris(row, khs), axis=1)

# Dictionary peminatan minimal 1 matkul
peminatan_dict = {
    'E-Business': {
        'PENGANTAR BISNIS DAN MANAJEMEN',
        'PENGANTAR BISNIS DIGITAL',
        'SISTEM INFORMASI AKUNTANSI'
    },
    'Enterprise': {
        'JAMINAN KUALITAS SISTEM INFORMASI',
        'SISTEM INFORMASI SDM',
        'ENTERPRISE RESOURCE PLANNING'
    },
    'User Experience': {
        'DASAR-DASAR DESAIN',
        'PRESENTASI DAN KOMUNIKASI VISUAL',
        'MULTIMEDIA INTERAKTIF'
    }
}

# Fungsi deteksi peminatan (minimal 1 matkul dari list)
def deteksi_peminatan(nim, df_khs):

    mk_all = set(df_khs[df_khs['NIM'] == nim]['Nama Mata Kuliah'].str.upper())
    for label, matkul_set in peminatan_dict.items():
        if mk_all.intersection(matkul_set):
            return label
    return 'Belum Teridentifikasi'

df_final['Peminatan'] = df_final['NIM'].apply(lambda nim: deteksi_peminatan(nim, khs))

# Fungsi risiko lulus
def risiko_lulus(row):
    ipk_risiko = row['IPK Total'] < IPK_MIN
    nilai_risiko = row['Nilai Akhir'] in RISK_GRADES
    sks_risiko = row["Status SKS"] in ["SKS Kurang", "Tidak Aktif"]
    return "Berpotensi Terlambat" if ipk_risiko or nilai_risiko or sks_risiko else "Aman"

df_final['Risiko Lulus'] = df_final.apply(risiko_lulus, axis=1)

# Simpan hasil akhir
df_final.to_excel("/content/drive/MyDrive/AKADEMIK KULIAH/(99) TUGAS AKHIR/Data TA/EWS 2024.xlsx", index=False)

# Cek hasil
df_final[['NIM', 'Nama', 'Semester', 'IPS', 'Status SKS', 'Peminatan', 'Risiko Lulus']].drop_duplicates().head()
# Out:
#           NIM                       Nama  Semester   IPS Status SKS  \
# 0   110124001      ANANDA YUFA NURHALIZA         1  3.49      Aktif
# 8   110124002      SHALAHUDDIN AL AYYUBI         1  3.70      Aktif
# 16  110124003  DAVID ALFARISI FRIYANDANA         1  3.65      Aktif
# 24  110124004               REZA MAULANA         1  3.69      Aktif
# 32  110124005               RICO RIWANTO         1  3.41      Aktif
#
#                 Peminatan Risiko Lulus
# 0   Belum Teridentifikasi         Aman
# 8   Belum Teridentifikasi         Aman
# 16  Belum Teridentifikasi         Aman
# 24  Belum Teridentifikasi         Aman
# 32  Belum Teridentifikasi         Aman
